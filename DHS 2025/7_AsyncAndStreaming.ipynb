# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import asyncio
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict, List

# Define state
class State(TypedDict):
    question: str
    answer: List[str]

# Our LLM (no streaming)
llm = ChatOpenAI(model="gpt-4o-mini")

# Node 1: Generate full answer
async def generate(state: State) -> State:
    print(f"\n[Generate] Question: {state['question']}")
    response = await llm.ainvoke(state["question"])   # no streaming, full response
    return {"answer": [response.content]}

# Node 2: Summarize answer
async def summarize(state: State) -> State:
    print("\n[Summarize] Processing...")
    summary = await llm.ainvoke("Summarize in one line: " + "".join(state["answer"]))
    return {"answer": [summary.content]}

# Build Graph
workflow = StateGraph(State)
workflow.add_node("generate", generate)
workflow.add_node("summarize", summarize)

workflow.add_edge(START, "generate")
workflow.add_edge("generate", "summarize")
workflow.add_edge("summarize", END)

# Compile graph
app = workflow.compile()

# One request handler
async def handle_request(question: str):
    inputs = {"question": question}
    print(f"\n===== Handling request: {question} =====")
    
    # No streaming — just run the graph
    result = await app.ainvoke(inputs)
    print(f"\nFinal Output for '{question}': {result['answer']}")
    return result

# Run multiple requests concurrently
async def main():
    questions = [
        "Explain async and streaming in simple terms",
        "What is LangGraph and why is it useful?",
        "Summarize the difference between sync and async programming",
    ]
    
    # Run all requests at once
    results = await asyncio.gather(*(handle_request(q) for q in questions))
    print("\n=== ALL RESULTS ===")
    for r in results:
        print(r)

# In Jupyter/Notebook: just use
await main()

# In a normal script, replace with:
# if __name__ == "__main__":
#     asyncio.run(main())
# Out:
# ===== Handling request: Explain async and streaming in simple terms =====
#
# ===== Handling request: What is LangGraph and why is it useful? =====
#
# ===== Handling request: Summarize the difference between sync and async programming =====
#
# [Generate] Question: Explain async and streaming in simple terms
#
# [Generate] Question: What is LangGraph and why is it useful?
#
# [Generate] Question: Summarize the difference between sync and async programming
#
# [Summarize] Processing...
#
# Final Output for 'Summarize the difference between sync and async programming': ['Synchronous programming executes tasks in a linear, blocking manner, while asynchronous programming enables concurrent task execution without blocking, enhancing efficiency and responsiveness but increasing complexity.']
#
# [Summarize] Processing...
#
# [Summarize] Processing...
#
# Final Output for 'What is LangGraph and why is it useful?': ['LangGraph is a framework that enhances the interaction and efficacy of language models in NLP tasks by utilizing graph-based representations for improved context management, knowledge retrieval, modularity, scalability, and interoperability.']
#
# Final Output for 'Explain async and streaming in simple terms': ['Async programming allows tasks to run simultaneously without waiting for each to finish, while streaming enables continuous data flow, processing it in real-time instead of waiting for complete sets.']
#
# === ALL RESULTS ===
# {'question': 'Explain async and streaming in simple terms', 'answer': ['Async programming allows tasks to run simultaneously without waiting for each to finish, while streaming enables continuous data flow, processing it in real-time instead of waiting for complete sets.']}
# {'question': 'What is LangGraph and why is it useful?', 'answer': ['LangGraph is a framework that enhances the interaction and efficacy of language models in NLP tasks by utilizing graph-based representations for improved context management, knowledge retrieval, modularity, scalability, and interoperability.']}
# {'question': 'Summarize the difference between sync and async programming', 'answer': ['Synchronous programming executes tasks in a linear, blocking manner, while asynchronous programming enables concurrent task execution without blocking, enhancing efficiency and responsiveness but increasing complexity.']}

# %%
import asyncio
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict, List

# Define state
class State(TypedDict):
    question: str
    answer: List[str]

# Our LLM
llm = ChatOpenAI(model="gpt-4o-mini", streaming=True)

# Node 1: Async Agent (generates answer tokens)
async def generate(state: State) -> State:
    print(f"\n[Generate] Question: {state['question']}")
    tokens = []
    async for chunk in llm.astream(state["question"]):
        if chunk.content:   # content is str
            print(chunk.content, end="", flush=True)
            tokens.append(chunk.content)
    print("\n--- generation complete ---")
    return {"answer": tokens}

# Node 2: Async Post-processor
async def summarize(state: State) -> State:
    print("\n[Summarize] Processing...")
    summary = await llm.ainvoke("Summarize in one line: " + "".join(state["answer"]))
    return {"answer": [summary.content]}

# Build Graph
workflow = StateGraph(State)
workflow.add_node("generate", generate)
workflow.add_node("summarize", summarize)

workflow.add_edge(START, "generate")
workflow.add_edge("generate", "summarize")
workflow.add_edge("summarize", END)

# Compile graph
app = workflow.compile()

# One request handler
async def handle_request(question: str):
    inputs = {"question": question}
    
    print(f"\n===== Handling request: {question} =====")
    async for event in app.astream(inputs):
        print(f"\n[STREAM EVENT] {event}")

    # Final state
    result = await app.ainvoke(inputs)
    print(f"\nFinal Output for '{question}': {result['answer']}")
    return result

# Run multiple requests concurrently
async def main():
    questions = [
        "Explain async and streaming in simple terms",
        "What is LangGraph and why is it useful?",
        "Summarize the difference between sync and async programming",
    ]
    
    # Run all requests at once
    results = await asyncio.gather(*(handle_request(q) for q in questions))
    print("\n=== ALL RESULTS ===")
    for r in results:
        print(r)

# Entry point
if __name__ == "__main__":
    await main()
# Out:
# ===== Handling request: Explain async and streaming in simple terms =====
#
# ===== Handling request: What is LangGraph and why is it useful? =====
#
# ===== Handling request: Summarize the difference between sync and async programming =====
#
# [Generate] Question: Explain async and streaming in simple terms
#
# [Generate] Question: What is LangGraph and why is it useful?
#
# [Generate] Question: Summarize the difference between sync and async programming
# The primary difference between synchronous (LangGraph issync)Sure! Let's break and asynchronous (async down "async") programming and " lies in a framework designed tostreaming facilitate the how tasks development of applications that leverage advanced" in simple terms language models:
#
# ### are executed and handled, particularly and graph Async (Asynchronous in relation to blocking)
#
# ** and nonAsync**,-blocking-based structures short for operations.
#
# ### S asynchronous, is aynchronous Programming way of:
# - handling tasks or operations **Execution without making the program Flow**. It wait for one task: In synchronous programming integrates various components,, tasks are executed to finish one after the other before starting including natural another., in Think of a sequential manner. it like ordering food Each task language processing at a must complete restaurant:
#
#  (N before the next one- WhenLP) begins.
#  and graph- ** you place-based representations your orderBlocking**: The, you don’t execution " have toblocks" wait at, to while waiting the counter enhance the capabilities of for a until your task to finish, applications such which can meal is ready. lead to Instead, as chatbots, inefficiencies if a information retrieval task involves you can sit down waiting for, maybe systems, and knowledge management external resources chat with tools.
#
#  (like### Key Features and I/O friends, operations).
# - ** Benefits:
#
# Simplicity**1. **Combining NLP and: It is typically and enjoy some drinks Graphs** easier to: LangGraph understand and allows users debug due to combine to its while waiting straightforward execution for the food to flow.
#
#  be prepared### As.
# - the strengths In programming, this meansynchronous Programming of NLP for understanding and generating human:
# - that while the computer is waiting language with the structural benefits of **Execution for something Flow** slow (: Inlike downloading asynchronous programming data from, tasks graphs for organizing can be executed concurrently, meaning that while and relating information.
#
# 2 one task. **Knowledge is waiting (e Representation**:.g., It enables for I the internet), it can continue/O operations to do efficient representation other things), other, like responding to tasks can your clicks run.
#  of knowledge through graph structures- **Non-block, whiching**: The program can can model or processing other information.
#
# ### continue executing Streaming
#
# **Streaming** refers to the continuous transmission of data other code instead of over the waiting for internet or the task complex relationships and interconnections between systems without needing to download to complete a complete, improving file before overall efficiency you can and responsiveness between entities.
#
# 3. **Enhanced Querying**.
# - start using it. **Complex: By using graph databases, Langity**: As It’s like watching a movieynchronous code can be online:
#
# - Instead more complex to writeGraph can facilitate and manage of waiting for the, often more complex querying capabilities than traditional database systems whole movie involving callbacks, promises to finish, allowing for richer interactions and, or async/ insights from data.
#
# await syntax to handle downloading before4. you start watching task completion, streaming and errors allows you.
#
# In **Contextual Understanding**: summary, to start synchronous programming waits for watching it tasks to The integration of language models almost immediately complete sequential, asly, the data while asynchronous is sent programming allows helps in in small for concurrent pieces ( execution, improving efficiencyor " understanding context and nuances but adding complexity. in user inputchunks")
# --- generation complete ---
#  over time
# [STREAM EVENT] {'generate': {'answer': ['The', ' primary', ' difference', ' between', ' synchronous', ' (', 'sync', ')', ' and', ' asynchronous', ' (', 'async', ')', ' programming', ' lies', ' in', ' how', ' tasks', ' are', ' executed', ' and', ' handled', ',', ' particularly', ' in', ' relation', ' to', ' blocking', ' and', ' non', '-block', 'ing', ' operations', '.\n\n', '###', ' S', 'ynchronous', ' Programming', ':\n', '-', ' **', 'Execution', ' Flow', '**', ':', ' In', ' synchronous', ' programming', ',', ' tasks', ' are', ' executed', ' one', ' after', ' the', ' other', ',', ' in', ' a', ' sequential', ' manner', '.', ' Each', ' task', ' must', ' complete', ' before', ' the', ' next', ' one', ' begins', '.\n', '-', ' **', 'Blocking', '**', ':', ' The', ' execution', ' "', 'blocks', '"', ' while', ' waiting', ' for', ' a', ' task', ' to', ' finish', ',', ' which', ' can', ' lead', ' to', ' ineff', 'iciencies', ' if', ' a', ' task', ' involves', ' waiting', ' for', ' external', ' resources', ' (', 'like', ' I', '/O', ' operations', ').\n', '-', ' **', 'S', 'imp', 'licity', '**', ':', ' It', ' is', ' typically', ' easier', ' to', ' understand', ' and', ' debug', ' due', ' to', ' its', ' straightforward', ' execution', ' flow', '.\n\n', '###', ' As', 'ynchronous', ' Programming', ':\n', '-', ' **', 'Execution', ' Flow', '**', ':', ' In', ' asynchronous', ' programming', ',', ' tasks', ' can', ' be', ' executed', ' concurrently', ',', ' meaning', ' that', ' while', ' one', ' task', ' is', ' waiting', ' (', 'e', '.g', '.,', ' for', ' I', '/O', ' operations', '),', ' other', ' tasks', ' can', ' run', '.\n', '-', ' **', 'Non', '-block', 'ing', '**', ':', ' The', ' program', ' can', ' continue', ' executing', ' other', ' code', ' instead', ' of', ' waiting', ' for', ' the', ' task', ' to', ' complete', ',', ' improving', ' overall', ' efficiency', ' and', ' responsiveness', '.\n', '-', ' **', 'Complex', 'ity', '**', ':', ' As', 'ynchronous', ' code', ' can', ' be', ' more', ' complex', ' to', ' write', ' and', ' manage', ',', ' often', ' involving', ' callbacks', ',', ' promises', ',', ' or', ' async', '/', 'await', ' syntax', ' to', ' handle', ' task', ' completion', ' and', ' errors', '.\n\n', 'In', ' summary', ',', ' synchronous', ' programming', ' waits', ' for', ' tasks', ' to', ' complete', ' sequential', 'ly', ',', ' while', ' asynchronous', ' programming', ' allows', ' for', ' concurrent', ' execution', ',', ' improving', ' efficiency', ' but', ' adding', ' complexity', '.']}}
#
# [Summarize] Processing...
# .
# - In computer, improving the accuracy and relevance applications, streaming is often used for audio, video, or large datasets, allowing of responses or actions taken by the application.
#
# 5. **Scalability for real-time access and consumption.
#
# ### Summary
#
#  and Flexibility- **Async** allows tasks**: LangGraph can be scaled to to run accommodate various concurrently, making programs applications, whether for small faster and more responsive, like ordering food and not personal projects waiting at or large the counter.
# - **Streaming** lets you receive and use data continuously as it enterprise solutions comes in, instead
# [STREAM EVENT] {'summarize': {'answer': ['Synchronous programming executes tasks sequentially with blocking waits, while asynchronous programming allows concurrent task execution without blocking, enhancing efficiency but increasing complexity.']}}
#
# [Generate] Question: Summarize the difference between sync and async programming
# .
#
# 6. **Inter of waiting for the entire thing to download, like watching a movie online while itoperability** downloads piece: It supports integration with various NLP tools and databases by piece.
#
# I, making it versatile for use hope that helps clarify in different technological ecosystems.
#
#  these concepts### Use!
# --- generation complete ---
#
# [STREAM EVENT] {'generate': {'answer': ['Sure', '!', " Let's", ' break', ' down', ' "', 'async', '"', ' and', ' "', 'stream', 'ing', '"', ' in', ' simple', ' terms', ':\n\n', '###', ' Async', ' (', 'As', 'ynchronous', ')\n\n', '**', 'Async', '**,', ' short', ' for', ' asynchronous', ',', ' is', ' a', ' way', ' of', ' handling', ' tasks', ' or', ' operations', ' without', ' making', ' the', ' program', ' wait', ' for', ' one', ' task', ' to', ' finish', ' before', ' starting', ' another', '.', ' Think', ' of', ' it', ' like', ' ordering', ' food', ' at', ' a', ' restaurant', ':\n\n', '-', ' When', ' you', ' place', ' your', ' order', ',', ' you', ' don', '’t', ' have', ' to', ' wait', ' at', ' the', ' counter', ' until', ' your', ' meal', ' is', ' ready', '.', ' Instead', ',', ' you', ' can', ' sit', ' down', ',', ' maybe', ' chat', ' with', ' friends', ',', ' and', ' enjoy', ' some', ' drinks', ' while', ' waiting', ' for', ' the', ' food', ' to', ' be', ' prepared', '.\n', '-', ' In', ' programming', ',', ' this', ' means', ' that', ' while', ' the', ' computer', ' is', ' waiting', ' for', ' something', ' slow', ' (', 'like', ' downloading', ' data', ' from', ' the', ' internet', '),', ' it', ' can', ' continue', ' to', ' do', ' other', ' things', ',', ' like', ' responding', ' to', ' your', ' clicks', ' or', ' processing', ' other', ' information', '.\n\n', '###', ' Streaming', '\n\n', '**', 'Streaming', '**', ' refers', ' to', ' the', ' continuous', ' transmission', ' of', ' data', ' over', ' the', ' internet', ' or', ' between', ' systems', ' without', ' needing', ' to', ' download', ' a', ' complete', ' file', ' before', ' you', ' can', ' start', ' using', ' it', '.', ' It', '’s', ' like', ' watching', ' a', ' movie', ' online', ':\n\n', '-', ' Instead', ' of', ' waiting', ' for', ' the', ' whole', ' movie', ' to', ' finish', ' downloading', ' before', ' you', ' start', ' watching', ',', ' streaming', ' allows', ' you', ' to', ' start', ' watching', ' it', ' almost', ' immediately', ',', ' as', ' the', ' data', ' is', ' sent', ' in', ' small', ' pieces', ' (', 'or', ' "', 'chunks', '")', ' over', ' time', '.\n', '-', ' In', ' computer', ' applications', ',', ' streaming', ' is', ' often', ' used', ' for', ' audio', ',', ' video', ',', ' or', ' large', ' datasets', ',', ' allowing', ' for', ' real', '-time', ' access', ' and', ' consumption', '.\n\n', '###', ' Summary', '\n\n', '-', ' **', 'Async', '**', ' allows', ' tasks', ' to', ' run', ' concurrently', ',', ' making', ' programs', ' faster', ' and', ' more', ' responsive', ',', ' like', ' ordering', ' food', ' and', ' not', ' waiting', ' at', ' the', ' counter', '.\n', '-', ' **', 'Streaming', '**', ' lets', ' you', ' receive', ' and', ' use', ' data', ' continuously', ' as', ' it', ' comes', ' in', ',', ' instead', ' of', ' waiting', ' for', ' the', ' entire', ' thing', ' to', ' download', ',', ' like', ' watching', ' a', ' movie', ' online', ' while', ' it', ' downloads', ' piece', ' by', ' piece', '.\n\n', 'I', ' hope', ' that', ' helps', ' clarify', ' these', ' concepts', '!']}}
#
# [Summarize] Processing...
#  Cases:
#
# - **Chatbots**: Creating intelligentSync ( conversational agents that cansynchronous understand user queries and) and async ( provide accurateasynchronous, context-aware responses) programming.
# - **Recommendation Systems** are two: Enhancing product or content different paradig recommendations byms for understanding the handling operations, particularly relationships between user preferences in relation to I, products/O tasks, and. Here existing data are the.
# - main differences **Knowledge:
#
# 1 Graphs. ****:Execution Flow**:
#    - Building and **S querying comprehensive knowledge graphsynchronous** that encaps: In synchronous programmingulate information in, tasks are executed a structured format, suitable one after the other. Each for complex
# [STREAM EVENT] {'summarize': {'answer': ['Async allows tasks to run concurrently without waiting, while streaming enables continuous data transmission without requiring complete downloads upfront.']}}
#
# [Generate] Question: Explain async and streaming in simple terms
#  task must data analysis and retrieval.
#
#  complete beforeOverall, Lang the next one startsGraph is, leading useful for developers and organizations to a looking to blocking operation build sophisticated. The applications that program waits require both for the robust language current task processing capabilities to finish before moving and the on.
#  ability to   - organize and **As analyze information in aynchronous** graph format.
# --- generation complete ---
#
# [STREAM EVENT] {'generate': {'answer': ['Lang', 'Graph', ' is', ' a', ' framework', ' designed', ' to', ' facilitate', ' the', ' development', ' of', ' applications', ' that', ' leverage', ' advanced', ' language', ' models', ' and', ' graph', '-based', ' structures', '.', ' It', ' integrates', ' various', ' components', ',', ' including', ' natural', ' language', ' processing', ' (', 'N', 'LP', ')', ' and', ' graph', '-based', ' representations', ',', ' to', ' enhance', ' the', ' capabilities', ' of', ' applications', ' such', ' as', ' chat', 'bots', ',', ' information', ' retrieval', ' systems', ',', ' and', ' knowledge', ' management', ' tools', '.\n\n', '###', ' Key', ' Features', ' and', ' Benefits', ':\n\n', '1', '.', ' **', 'Comb', 'ining', ' NLP', ' and', ' Graph', 's', '**', ':', ' Lang', 'Graph', ' allows', ' users', ' to', ' combine', ' the', ' strengths', ' of', ' NLP', ' for', ' understanding', ' and', ' generating', ' human', ' language', ' with', ' the', ' structural', ' benefits', ' of', ' graphs', ' for', ' organizing', ' and', ' relating', ' information', '.\n\n', '2', '.', ' **', 'Knowledge', ' Representation', '**', ':', ' It', ' enables', ' efficient', ' representation', ' of', ' knowledge', ' through', ' graph', ' structures', ',', ' which', ' can', ' model', ' complex', ' relationships', ' and', ' inter', 'connections', ' between', ' entities', '.\n\n', '3', '.', ' **', 'Enhanced', ' Query', 'ing', '**', ':', ' By', ' using', ' graph', ' databases', ',', ' Lang', 'Graph', ' can', ' facilitate', ' more', ' complex', ' querying', ' capabilities', ' than', ' traditional', ' database', ' systems', ',', ' allowing', ' for', ' richer', ' interactions', ' and', ' insights', ' from', ' data', '.\n\n', '4', '.', ' **', 'Context', 'ual', ' Understanding', '**', ':', ' The', ' integration', ' of', ' language', ' models', ' helps', ' in', ' understanding', ' context', ' and', ' nuances', ' in', ' user', ' input', ',', ' improving', ' the', ' accuracy', ' and', ' relevance', ' of', ' responses', ' or', ' actions', ' taken', ' by', ' the', ' application', '.\n\n', '5', '.', ' **', 'Sc', 'al', 'ability', ' and', ' Flex', 'ibility', '**', ':', ' Lang', 'Graph', ' can', ' be', ' scaled', ' to', ' accommodate', ' various', ' applications', ',', ' whether', ' for', ' small', ' personal', ' projects', ' or', ' large', ' enterprise', ' solutions', '.\n\n', '6', '.', ' **', 'Inter', 'oper', 'ability', '**', ':', ' It', ' supports', ' integration', ' with', ' various', ' NLP', ' tools', ' and', ' databases', ',', ' making', ' it', ' versatile', ' for', ' use', ' in', ' different', ' technological', ' ecosystems', '.\n\n', '###', ' Use', ' Cases', ':\n\n', '-', ' **', 'Chat', 'bots', '**', ':', ' Creating', ' intelligent', ' conversational', ' agents', ' that', ' can', ' understand', ' user', ' queries', ' and', ' provide', ' accurate', ',', ' context', '-aware', ' responses', '.\n', '-', ' **', 'Recommendation', ' Systems', '**', ':', ' Enh', 'ancing', ' product', ' or', ' content', ' recommendations', ' by', ' understanding', ' the', ' relationships', ' between', ' user', ' preferences', ',', ' products', ',', ' and', ' existing', ' data', '.\n', '-', ' **', 'Knowledge', ' Graph', 's', '**', ':', ' Building', ' and', ' querying', ' comprehensive', ' knowledge', ' graphs', ' that', ' encaps', 'ulate', ' information', ' in', ' a', ' structured', ' format', ',', ' suitable', ' for', ' complex', ' data', ' analysis', ' and', ' retrieval', '.\n\n', 'Overall', ',', ' Lang', 'Graph', ' is', ' useful', ' for', ' developers', ' and', ' organizations', ' looking', ' to', ' build', ' sophisticated', ' applications', ' that', ' require', ' both', ' robust', ' language', ' processing', ' capabilities', ' and', ' the', ' ability', ' to', ' organize', ' and', ' analyze', ' information', ' in', ' a', ' graph', ' format', '.']}}
#
# [Summarize] Processing...
# : In asynchronous programming, tasks can be executed independently of one another. An operationSure! can be Let's break down the initiated, and the concepts of program can **async** ( continue executingasynchronous) and other tasks **stream while waitinging** for the operation to into simple complete. terms:
#
#  This non-blocking### Async behavior allows for more efficient use (As of systemynchronous)
#
# Imagine you're resources.
#
#  cooking dinner2.. You **Performance might put**:
#  a pot
# [STREAM EVENT] {'summarize': {'answer': ['LangGraph is a framework that integrates natural language processing and graph structures to enhance application development for chatbots, information retrieval, and knowledge management systems.']}}
#
# [Generate] Question: What is LangGraph and why is it useful?
#  of water   - on the stove to **Synchronous** boil,: Can lead to but instead inefficiencies, especially of just in I waiting by/O-bound the stove tasks ( and doinglike file nothing while reading, network callsLangGraph it heats is a), as framework designed for building the program applications that remains idle incorporate natural up, language processing (N while waitingLP) for operations capabilities with a focus to complete on the manipulation of.
#    large language - ** you might models (AsynchronousLLMs chop vegetables) using graph-based**: or set the table structures. More efficient Its utility. In lies in for I several key/O-bound areas:
#
#  this scenario1. tasks as **Structured Knowledge Representation it helps**:, you're LangGraph avoid idle allows users multitasking time. to represent complex information.
#
#  It allows and relationships in a for concurrency structured formatIn the which can, where world of be more easily navig multiple operationsated and programming, can be understood by **as LLM in progresss.ynchronous** refers to This facilitates at the tasks such same time as knowledge the ability retrieval and without waiting to perform for each dynamic content generation.
#
#  to finish2..
#
# 3 **Integration. ** with LLMsComplexity tasks independently**: By utilizing**:
#  graphs,   - LangGraph **S can help without waiting enhance the interactions with for oneynchronous** LLMs, enabling better: Generally contextual understanding simpler to and more refined responses. Graph understand ands can represent entities, their task to attributes, and the relationships between them, reason about finish before which can improve the model's comprehension of because the nuanced queries.
#
# 3 flow of. ** execution isInteractivity**: LangGraph supports interactive starting another linear and. When applications that one process is waiting (like your pot allow users predictable.
#  of water to query boiling), and manipulate   - the program can continue executing other data and receive responses tasks ( **As based onlike choppingynchronous** a graph veggies). structure. This makes programs more: Can efficient, especially when This leads introduce complexity to more engaging dealing with things like downloading files, requiring and informative or making careful handling user experiences.
#
# 4. **Enhanced of callbacks network requests Performance on, promises, where, or Specific Tasks async/**: you don'tawait constructs By structuring information in a to manage want to sit idle the flow graph format, LangGraph can of operations improve performance waiting for and avoid on specific a response tasks like issues like recommendation systems.
#
# ### callback hell, chat Streaming
#
# Now,bots, think about how you and conversational agents, listen to where understanding complex relationships is crucial music..
#
# 5. **Scal Instead ofability**: Graph methods can downloading an be more and race entire album scalable for certain processing tasks, before you allowing for can start the handling of larger listening, conditions.
#
#  datasets efficiently music streaming. This is particularly beneficial in services let enterprise applications you listen and research4. environments where large volumes to songs of information must be processed effectively almost instantly.
#
# In **Use summary, while they LangGraph bridges the gap between continue downloading traditional knowledge management approaches and modern Cases** NLP by in the leveraging the background. strengths of graph theory in conjunction You can with advanced:
#    play, language models pause, and skip, making it a powerful tool tracks without - ** for developers and researchers in the waiting for field.
# --- generation complete ---
#
# [Summarize] Processing...
#  the whole album toSynchronous be saved to your device first**:.
#
# **Streaming** refers to Suitable for the process of transmitting data continuously in small pieces instead tasks where of sending the entire order of file at once. This is execution matters often used for video and audio content over and where the internet. It
# Final Output for 'What is LangGraph and why is it useful?': ['LangGraph is a framework that enhances natural language processing applications by employing graph-based structures for structured knowledge representation, improved LLM integration, interactivity, task-specific performance, and scalability.']
#  allows users to start consuming data the operations (like watching a video) almost immediately while the rest of do not the data is still involve waiting being received.
#
# ### Summary
#
# - on external **Async (As resources.
# ynchronous)**: Doing multiple things   - at once **As without waitingynchronous** for one: Ideal task to for tasks finish before starting another that involve waiting for.
# - external resources **Streaming, such**: as web requests, Sending data file I in small/O, chunks so or any long-running you can tasks that would otherwise start using block the main thread it right.
#
# In away, summary, rather than synchronous programming waiting for executes tasks the entire sequentially file.
#
#  and isBoth concepts straightforward, while asynchronous help improve programming allows efficiency and for concurrent user experience execution, improving performance in technology!
# --- generation complete ---
#
# [Summarize] Processing...
#  but increasing complexity.
# --- generation complete ---
#
# [Summarize] Processing...
#
# Final Output for 'Explain async and streaming in simple terms': ['Async (Asynchronous) involves multitasking and performing independent tasks simultaneously without waiting for one to finish, while Streaming allows data to be transmitted continuously in small pieces for immediate access rather than waiting for a complete file.']
#
# Final Output for 'Summarize the difference between sync and async programming': ['Synchronous programming executes tasks one after another in a blocking manner, while asynchronous programming allows concurrent task execution, enhancing performance at the cost of increased complexity.']
#
# === ALL RESULTS ===
# {'question': 'Explain async and streaming in simple terms', 'answer': ['Async (Asynchronous) involves multitasking and performing independent tasks simultaneously without waiting for one to finish, while Streaming allows data to be transmitted continuously in small pieces for immediate access rather than waiting for a complete file.']}
# {'question': 'What is LangGraph and why is it useful?', 'answer': ['LangGraph is a framework that enhances natural language processing applications by employing graph-based structures for structured knowledge representation, improved LLM integration, interactivity, task-specific performance, and scalability.']}
# {'question': 'Summarize the difference between sync and async programming', 'answer': ['Synchronous programming executes tasks one after another in a blocking manner, while asynchronous programming allows concurrent task execution, enhancing performance at the cost of increased complexity.']}
